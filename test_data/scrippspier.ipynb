# %%
import geopandas as gpd

# %%
import fiona

# %%
gpd.read_file('/home/scott/projects/RedTideResearch/test_data/SoCalData/HABs-ScrippsPier_5bbe_7a9c_9866.csv')
# Out:
#         latitude     longitude depth  SampleID Location_Code  \
# 0  degrees_north  degrees_east     m
# 1         32.867      -117.257   NaN  20191007           SIO
# 2         32.867      -117.257   NaN  20191014           SIO
#
#                    time     Temp Air_Temp Salinity Chl_Volume_Filtered  ...  \
# 0                   UTC  celsius  celsius                           mL  ...
# 1  2019-10-07T17:30:00Z     19.3      NaN      NaN                 100  ...
# 2  2019-10-14T17:16:00Z     18.9      NaN      NaN                 100  ...
#
#   Prorocentrum_spp Pseudo_nitzschia_delicatissima_group  \
# 0          cells/L                              cells/L
# 1          33167.0                              85109.0
# 2          17523.0                              63832.0
#
#   Pseudo_nitzschia_seriata_group Ceratium Cochlodinium Gymnodinium_spp  \
# 0                        cells/L  cells/L      cells/L         cells/L
# ...

# %%
import folium

# %%
m = folium.Map(location[42.3601, -71.0589], zoom_start=12)
